# %%
# %pip install astro-datalab
# %pip install python-dotenv
# Out:
# ^C
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap_external>", line 153, in _path_is_mode_type
#   File "<frozen importlib._bootstrap_external>", line 147, in _path_stat
# FileNotFoundError: [Errno 2] No such file or directory: '/home/nattan/miniconda3/envs/yolo_novo/lib/python3.10/site-packages/pip/_internal/commands/__init__.cpython-310-x86_64-linux-gnu.so'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nattan/miniconda3/envs/yolo_novo/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/nattan/miniconda3/envs/yolo_novo/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/nattan/miniconda3/envs/yolo_novo/lib/python3.10/site-packages/pip/__main__.py", line 24, in <module>
#     sys.exit(_main())
#   File "/home/nattan/miniconda3/envs/yolo_novo/lib/python3.10/site-packages/pip/_internal/cli/main.py", line 47, in main
#     from pip._internal.cli.autocompletion import autocomplete
#   File "/home/nattan/miniconda3/envs/yolo_novo/lib/python3.10/site-packages/pip/_internal/cli/autocompletion.py", line 12, in <module>
#     from pip._internal.cli.main_parser import create_main_parser
#   File "/home/nattan/miniconda3/envs/yolo_novo/lib/python3.10/site-packages/pip/_internal/cli/main_parser.py", line 14, in <module>
#     from pip._internal.commands import commands_dict, get_similar_commands
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1002, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 945, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1439, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1411, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1563, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 161, in _path_isfile
#   File "<frozen importlib._bootstrap_external>", line 153, in _path_is_mode_type
# KeyboardInterrupt
# Note: you may need to restart the kernel to use updated packages.
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.2.2
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /home/nattan/miniconda3/envs/yolo_novo/lib/python3.10/site-packages (1.26.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Imports necessários

# %%
import pandas as pd
import time
import pandas as pd
import requests
import os
from io import StringIO

# %% [markdown]
# ## Baixa os fits G,R,I,Z e o catalogo dos campos presentes no array bricks, salvando no repositório /data/raw/images/dr10/south.

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

bricks = ["0030m292","0030m295","0030m297","0030m300","0030m302","0030m307","0030m310","0030m312","0030m380", "0030m390","0001m007","0001m010","0001m012","0001m015","0001m017","0001m022",
         "0001m035","0001m042","0001m047","0001m052","0010m350","0010m352","0010m367","0011m412","0011p002","0011p005","0011p017","0011p027","0011p045","0011p047",
         "0011p050","0020m575","0021m005","0021m007","0021m010","0021m017","0021m020","0021m040","0021m402","0021m510","0021m585","0021p005","0040m397","0040m400"
         ,"0040m402","0040m445","0040m495","0040m540","0040m585","0040m622","0041m020","0041m042","0041m065","0041m087","0041m090","0041m462",
         "0041m470","0041m505","0041m512","0041m592","0041m595","0041p010","0041p012","0041p030","0042m325","0042m377","0042m422","0042m432","0042m472",
         "0042m605","0043m042","0043m050","0043m067","0043m342","0043m387","0043m392","0043m445","0043m487","0043m490","0043m567","0043m570","0043m575","0050m140","0050m142","0050m145","0050m300",
         "0050m302","0050m347","0050m355","0050m357","0050m402","0050m515","0050m552","0051m047","0051m062","0051m097","0051m320","0051m450","0051m487"
         ,"0051m495","0051m625","0051p037","0051p045","0052m470","0053m012","0053m017","0053m035","0060m125","0060m440","0060m530","0060m592","0030m297"]
for i in range(len(bricks)):  # baixa os dados de cada campo
    brick_name = bricks[i]
    prefix = brick_name[:3]
    # URL oDR10 South
    base_url = f"https://portal.nersc.gov/cfs/cosmo/data/legacysurvey/dr10/south/coadd/{prefix}/{brick_name}/"
    files_to_download = {
      "banda_g": f"legacysurvey-{brick_name}-image-g.fits.fz",
      "banda_r": f"legacysurvey-{brick_name}-image-r.fits.fz",
      "banda_i": f"legacysurvey-{brick_name}-image-i.fits.fz",
       "banda_z": f"legacysurvey-{brick_name}-image-z.fits.fz",
       "catalogo": f"tractor-{brick_name}.fits"
    }
    save_path = f"./data/raw/images/dr10/south/{prefix}/{brick_name}/" # arquivo onde vai falvar os fitz
    os.makedirs(save_path, exist_ok=True) 
    print(f"\n--- Iniciando Brick {i+1}: {brick_name} ---")

    for key, filename in files_to_download.items():
            if key == "catalogo":
                url = f"https://portal.nersc.gov/cfs/cosmo/data/legacysurvey/dr10/south/tractor/{prefix}/"+filename
            else:
                url = base_url + filename
            path = os.path.join(save_path, filename)
            if os.path.exists(path) and os.path.getsize(path) > 1024:#  pula o download se já existir o arquvio e não estiver vazio ( > 1KB)
                print(f"{filename} já existe e parece íntegro. Pulando...")
                continue
            print(f"Baixando {key}...")
            try:
                with requests.get(url, stream=True, timeout=60, headers=headers) as r: # Adicionando Headers e Timeout
                    if r.status_code == 200:
                        with open(path, 'wb') as f:
                            for chunk in r.iter_content(chunk_size=1024*1024): # Chunk de 1MB é mais rápido
                                if chunk:
                                    f.write(chunk)
                        if os.path.getsize(path) < 1024: # checagem se baixou o conteúdo do arquivo ou deu algum tipo de erro
                            print(f"!!! ERRO: {filename} baixou vazio. Removendo...")
                            os.remove(path)
                        else:
                            print(f" OK: {filename} salvo ({os.path.getsize(path)/1024/1024:.2f} MB)")
                    else:
                        print(f" Erro {r.status_code} no brick {brick_name}.")
            except Exception as e:
                print(f" Erro na conexão: {e}")
                # Se deu erro no meio do download, remove o arquivo quebrado
                if os.path.exists(path):
                    os.remove(path)

print("bricks prontos")
# Out:
# --- Iniciando Brick 1: 0030m292 ---
# legacysurvey-0030m292-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m292-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m292-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m292-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0030m292.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 2: 0030m295 ---
# legacysurvey-0030m295-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m295-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m295-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m295-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0030m295.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 3: 0030m297 ---
# legacysurvey-0030m297-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m297-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m297-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m297-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0030m297.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 4: 0030m300 ---
# legacysurvey-0030m300-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m300-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m300-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m300-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0030m300.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 5: 0030m302 ---
# legacysurvey-0030m302-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m302-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m302-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m302-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0030m302.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 6: 0030m307 ---
# legacysurvey-0030m307-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m307-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m307-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m307-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0030m307.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 7: 0030m310 ---
# legacysurvey-0030m310-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m310-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m310-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m310-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0030m310.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 8: 0030m312 ---
# legacysurvey-0030m312-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m312-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m312-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m312-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0030m312.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 9: 0030m380 ---
# legacysurvey-0030m380-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m380-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m380-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m380-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0030m380.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 10: 0030m390 ---
# legacysurvey-0030m390-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m390-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m390-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m390-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0030m390.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 11: 0001m007 ---
# legacysurvey-0001m007-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0001m007-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0001m007-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0001m007-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0001m007.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 12: 0001m010 ---
# legacysurvey-0001m010-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0001m010-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0001m010-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0001m010-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0001m010.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 13: 0001m012 ---
# legacysurvey-0001m012-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0001m012-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0001m012-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0001m012-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0001m012.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 14: 0001m015 ---
# legacysurvey-0001m015-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0001m015-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0001m015-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0001m015-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0001m015.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 15: 0001m017 ---
# legacysurvey-0001m017-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0001m017-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0001m017-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0001m017-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0001m017.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick
image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0043m575-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0043m575-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0043m575.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 83: 0050m140 ---
# legacysurvey-0050m140-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m140-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m140-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m140-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0050m140.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 84: 0050m142 ---
# legacysurvey-0050m142-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m142-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m142-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m142-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0050m142.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 85: 0050m145 ---
# legacysurvey-0050m145-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m145-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m145-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m145-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0050m145.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 86: 0050m300 ---
# legacysurvey-0050m300-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m300-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m300-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m300-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0050m300.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 87: 0050m302 ---
# legacysurvey-0050m302-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m302-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m302-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m302-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0050m302.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 88: 0050m347 ---
# legacysurvey-0050m347-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m347-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m347-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m347-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0050m347.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 89: 0050m355 ---
# legacysurvey-0050m355-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m355-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m355-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m355-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0050m355.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 90: 0050m357 ---
# legacysurvey-0050m357-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m357-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m357-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m357-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0050m357.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 91: 0050m402 ---
# legacysurvey-0050m402-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m402-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m402-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m402-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0050m402.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 92: 0050m515 ---
# legacysurvey-0050m515-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m515-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m515-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m515-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0050m515.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 93: 0050m552 ---
# legacysurvey-0050m552-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m552-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m552-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0050m552-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0050m552.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 94: 0051m047 ---
# legacysurvey-0051m047-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m047-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m047-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m047-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0051m047.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 95: 0051m062 ---
# legacysurvey-0051m062-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m062-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m062-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m062-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0051m062.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 96: 0051m097 ---
# legacysurvey-0051m097-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m097-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m097-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m097-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0051m097.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 97: 0051m320 ---
# legacysurvey-0051m320-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m320-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m320-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m320-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0051m320.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 98: 0051m450 ---
# legacysurvey-0051m450-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m450-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m450-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m450-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0051m450.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 99: 0051m487 ---
# legacysurvey-0051m487-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m487-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m487-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m487-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0051m487.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 100: 0051m495 ---
# legacysurvey-0051m495-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m495-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m495-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m495-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0051m495.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 101: 0051m625 ---
# legacysurvey-0051m625-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m625-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m625-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051m625-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0051m625.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 102: 0051p037 ---
# legacysurvey-0051p037-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051p037-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051p037-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051p037-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0051p037.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 103: 0051p045 ---
# legacysurvey-0051p045-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051p045-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051p045-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0051p045-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0051p045.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 104: 0052m470 ---
# legacysurvey-0052m470-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0052m470-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0052m470-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0052m470-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0052m470.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 105: 0053m012 ---
# legacysurvey-0053m012-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0053m012-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0053m012-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0053m012-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0053m012.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 106: 0053m017 ---
# legacysurvey-0053m017-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0053m017-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0053m017-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0053m017-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0053m017.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 107: 0053m035 ---
# legacysurvey-0053m035-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0053m035-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0053m035-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0053m035-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0053m035.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 108: 0060m125 ---
# legacysurvey-0060m125-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0060m125-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0060m125-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0060m125-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0060m125.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 109: 0060m440 ---
# legacysurvey-0060m440-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0060m440-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0060m440-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0060m440-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0060m440.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 110: 0060m530 ---
# legacysurvey-0060m530-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0060m530-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0060m530-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0060m530-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0060m530.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 111: 0060m592 ---
# legacysurvey-0060m592-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0060m592-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0060m592-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0060m592-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0060m592.fits já existe e parece íntegro. Pulando...
#
# --- Iniciando Brick 112: 0030m297 ---
# legacysurvey-0030m297-image-g.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m297-image-r.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m297-image-i.fits.fz já existe e parece íntegro. Pulando...
# legacysurvey-0030m297-image-z.fits.fz já existe e parece íntegro. Pulando...
# tractor-0030m297.fits já existe e parece íntegro. Pulando...
# bricks prontos

# %%
print(len(bricks))
# Out:
# 112
